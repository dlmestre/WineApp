# %% [markdown]
# wine-search API
#
# access: cuvees

# %%
import json
import pandas as pd
import lxml
import urllib
from xml.etree import ElementTree as ET

# %%
url = r"http://api.wine-searcher.com/wine-select-api.lml?Xkey=cuvees&Xkeyword_mode=A&Xwinename=petrus&Xvintage=2012&Xlocation=hong+kong&Xcurrencycode=hkd"

root = ET.parse(urllib.urlopen(url)).getroot()

# %%
for name in root.findall("./wines/wine"):
    for i in name:
        print i.text,i.tag
# Out:
# iDealwine Hong Kong merchant
# None merchant-description
# None physical-address
# None zip-code
# None zip-code-miles
# None latitude
# None longitude
# None geo-miles
# Hong Kong country
# None state
# None contact-phone
# petrus wine-description
# 2012 vintage
# 12,255.56 price
# AUCTION:Bottle bottle-size
# http://www.wine-searcher.com/redirect.lml?from_type_F=A&from_page_F=cuvees&wine_id_F=20288&merchant_id_F=62390&Xwinename=petrus&Xvintage_F=2012&Xlocation=Hong+Kong&Xstate=&Xcurrencycode=HKD&page_no_F=1&line_no_F=1&uid_F= link
# iDealwine Hong Kong merchant
# None merchant-description
# None physical-address
# None zip-code
# None zip-code-miles
# None latitude
# None longitude
# ...

# %%
zip(None,None)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-c86db6684c67> in <module>()
# ----> 1 zip(None,None)
#
# TypeError: zip argument #1 must support iteration
